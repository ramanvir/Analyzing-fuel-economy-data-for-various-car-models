# %% [markdown]
# # Filter, Drop Nulls, Dedupe
# Use `data_08_v1.csv` and `data_18_v1.csv`. You should've created these data files in the previous section: *Cleaning Column Labels*.

# %%
# load datasets
import pandas as pd

df_08 = pd.read_csv('data_08_v1.csv')
df_18 = pd.read_csv('data_18_v1.csv')

# %%
# view dimensions of dataset
df_08.shape
# Out:
# (2404, 14)

# %%
# view dimensions of dataset
df_18.shape
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  veh_class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 0                    3       20      28      23                     5       No

# %% [markdown]
# ## Filter by Certification Region

# %%
# filter datasets for rows following California standards
df_08 = df_08.query("cert_region == 'CA'")
df_18 = df_18.query("cert_region == 'CA'")

# %%
# confirm only certification region is California
df_08['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# confirm only certification region is California
df_18['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
# drop certification region columns form both datasets

#df_18.drop('cert_region', axis = 1, inplace = True)
df_08.drop('cert_region', axis = 1, inplace = True)

# %%
df_08.shape
# Out:
# (1084, 13)

# %%
df_18.shape
# Out:
# (798, 14)

# %% [markdown]
# ## Drop Rows with Missing Values

# %%
# view missing value count for each feature in 2008
df_08.isnull().sum()
# Out:
# model                    0
# displ                    0
# cyl                     75
# trans                   75
# drive                   37
# fuel                     0
# veh_class                0
# air_pollution_score      0
# city_mpg                75
# hwy_mpg                 75
# cmb_mpg                 75
# greenhouse_gas_score    75
# smartway                 0
# dtype: int64

# %%
# view missing value count for each feature in 2018
df_18.isnull().sum()
# Out:
# model                   0
# displ                   1
# cyl                     1
# trans                   0
# drive                   0
# fuel                    0
# cert_region             0
# veh_class               0
# air_pollution_score     0
# city_mpg                0
# hwy_mpg                 0
# cmb_mpg                 0
# greenhouse_gas_score    0
# smartway                0
# dtype: int64

# %%
# drop rows with any null values in both datasets
df_08.dropna(axis=0, inplace=True)
df_18.dropna(axis=0, inplace=True)

# %%
# checks if any of columns in 2008 have null values - should print False
df_08.isnull().sum().any()
# Out:
# False

# %%
# checks if any of columns in 2018 have null values - should print False
df_18.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ## Dedupe Data

# %%
# print number of duplicates in 2008 and 2018 datasets
print(df_08.duplicated().sum())
df_18.duplicated().sum()
# Out:
# 23
# 3

# %%
# drop duplicates in both datasets

df_08.drop_duplicates(inplace=True)
df_18.drop_duplicates(inplace=Tru)
# Out:
#                           model  displ  cyl       trans drive  \
# 1                     ACURA RDX    3.5  6.0  SemiAuto-6   2WD
# 3                     ACURA RDX    3.5  6.0  SemiAuto-6   4WD
# 4                     ACURA TLX    2.4  4.0       AMS-8   2WD
# 6                     ACURA TLX    3.5  6.0  SemiAuto-9   2WD
# 8                     ACURA TLX    3.5  6.0  SemiAuto-9   4WD
# 10         ACURA TLX AWD A-SPEC    3.5  6.0  SemiAuto-9   4WD
# 12         ACURA TLX FWD A-SPEC    3.5  6.0  SemiAuto-9   2WD
# 14                ALFA ROMEO 4C    1.8  4.0   AutoMan-6   2WD
# 17            ALFA ROMEO Giulia    2.9  6.0      Auto-8   2WD
# 22                      AUDI A3    2.0  4.0       AMS-6   4WD
# 24                      AUDI A3    2.0  4.0       AMS-7   2WD
# 26            AUDI A3 Cabriolet    2.0  4.0       AMS-6   4WD
# 28            AUDI A3 Cabriolet    2.0  4.0       AMS-7   2WD
# 30                      AUDI A4    2.0  4.0       AMS-7   4WD
# 32                      AUDI A4    2.0  4.0       Man-6   4WD
# 34                AUDI A4 Ultra    2.0  4.0       AMS-7   2WD
# 36                      AUDI A5    2.0  4.0       AMS-7   4WD
# 38                      AUDI A5    2.0  4.0       Man-6   4WD
# 40            AUDI A5 Cabriolet    2.0  4.0       AMS-7   4WD
# 42    AUDI A5 Sportback quattro    2.0  4.0       AMS-7   4WD
# 44                      AUDI A6    2.0  4.0       AMS-7   2WD
# 46                      AUDI A6    2.0  4.0  SemiAuto-8   4WD
# 49                      AUDI A6    3.0  6.0  SemiAuto-8   4WD
# 51                      AUDI A7    3.0  6.0  SemiAuto-8   4WD
# 53                    AUDI A8 L    3.0  6.0  SemiAuto-8   4WD
# 55                      AUDI Q3    2.0  4.0  SemiAuto-6   2WD
# 57                      AUDI Q3    2.0  4.0  SemiAuto-6   4WD
# 58                      AUDI Q5    2.0  4.0  SemiAuto-7   4WD
# 60                      AUDI Q7    2.0  4.0  SemiAuto-8   4WD
# 63                      AUDI Q7    3.0  6.0  SemiAuto-8   4WD
# ...                         ...    ...  ...         ...   ...
# 1551        VOLVO Atlas 4Motion    3.6  6.0  SemiAuto-8   4WD
# 1553                  VOLVO S60    2.0  4.0  SemiAuto-8   2WD
# 1555                  VOLVO S60    2.0  4.0  SemiAuto-8   4WD
# 1556                  VOLVO S60    2.0  4.0  SemiAuto-8   4WD
# 1559               VOLVO S60 CC    2.0  4.0  SemiAuto-8   4WD
# 1561      VOLVO S60 Inscription    2.0  4.0  SemiAuto-8   2WD
# 1563      VOLVO S60 Inscription    2.0  4.0  SemiAuto-8   4WD
# 1565         VOLVO S60 Polestar    2.0  4.0  SemiAuto-8   4WD
# 1567                  VOLVO S90    2.0  4.0  SemiAuto-8   2WD
# 1569                  VOLVO S90    2.0  4.0  SemiAuto-8   4WD
# 1570                  VOLVO S90    2.0  4.0  SemiAuto-8   4WD
# 1573                  VOLVO S90    2.0  4.0  SemiAuto-8   4WD
# 1575                  VOLVO S90    2.0  4.0  SemiAuto-8   4WD
# 1577                  VOLVO S90    2.0  4.0  SemiAuto-8   4WD
# 1579                  VOLVO V60    2.0  4.0  SemiAuto-8   2WD
# 1581                  VOLVO V60    2.0  4.0  SemiAuto-8   4WD
# 1582                  VOLVO V60    2.0  4.0  SemiAuto-8   4WD
# 1585               VOLVO V60 CC    2.0  4.0  SemiAuto-8   4WD
# 1587         VOLVO V60 Polestar    2.0  4.0  SemiAuto-8   4WD
# 1589                  VOLVO V90    2.0  4.0  SemiAuto-8   2WD
# 1591                  VOLVO V90    2.0  4.0  SemiAuto-8   4WD
# 1593               VOLVO V90 CC    2.0  4.0  SemiAuto-8   4WD
# 1595               VOLVO V90 CC    2.0  4.0  SemiAuto-8   4WD
# 1597                VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD
# 1599                VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD
# 1601                VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD
# 1603                VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD
# 1605                VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
# 1607                VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
# 1609                VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
#
#                       fuel cert_region      veh_class  air_pollution_score  \
# 1                 Gasoline          CA      small SUV                    3
# 3                 Gasoline          CA      small SUV                    3
# 4                 Gasoline          CA      small car                    3
# 6                 Gasoline          CA      small car                    3
# 8                 Gasoline          CA      small car                    3
# 10                Gasoline          CA      small car                    3
# 12                Gasoline          CA      small car                    3
# 14                Gasoline          CA      small car                    1
# 17                Gasoline          CA    midsize car                    3
# 22                Gasoline          CA      small car                    7
# 24                Gasoline          CA      small car                    7
# 26                Gasoline          CA      small car                    7
# 28                Gasoline          CA      small car                    7
# 30                Gasoline          CA      small car                    5
# 32                Gasoline          CA      small car                    3
# 34                Gasoline          CA      small car                    3
# 36                Gasoline          CA      small car                    5
# 38                Gasoline          CA      small car                    3
# 40                Gasoline          CA      small car                    5
# 42                Gasoline          CA    midsize car                    5
# 44                Gasoline          CA    midsize car                    5
# 46                Gasoline          CA    midsize car                    5
# 49                Gasoline          CA    midsize car                    3
# 51                Gasoline          CA    midsize car                    3
# 53                Gasoline          CA      large car                    3
# 55                Gasoline          CA      small car                    3
# 57                Gasoline          CA      small car                    3
# 58                Gasoline          CA      small SUV                    3
# 60                Gasoline          CA   standard SUV                    3
# 63                Gasoline          CA   standard SUV                    3
# ...                    ...         ...            ...                  ...
# 1551              Gasoline          CA      small SUV                    5
# 1553              Gasoline          CA      small car                    7
# 1555              Gasoline          CA      small car                    3
# 1556              Gasoline          CA      small car                    3
# 1559              Gasoline          CA      small car                    3
# 1561              Gasoline          CA      small car                    3
# 1563              Gasoline          CA      small car                    3
# 1565              Gasoline          CA      small car                    1
# 1567              Gasoline          CA    midsize car                    3
# 1569              Gasoline          CA    midsize car                    3
# 1570              Gasoline          CA    midsize car                    3
# 1573              Gasoline          CA    midsize car                    5
# 1575              Gasoline          CA    midsize car                    5
# 1577  Gasoline/Electricity          CA    midsize car                    7
# 1579              Gasoline          CA  station wagon                    3
# 1581              Gasoline          CA  station wagon                    3
# 1582              Gasoline          CA  station wagon                    3
# 1585              Gasoline          CA  station wagon                    3
# 1587              Gasoline          CA  station wagon                    1
# 1589              Gasoline          CA  station wagon                    5
# 1591              Gasoline          CA  station wagon                    5
# 1593              Gasoline          CA  station wagon                    5
# 1595              Gasoline          CA  station wagon                    5
# 1597              Gasoline          CA      small SUV                    5
# 1599              Gasoline          CA      small SUV                    5
# 1601  Gasoline/Electricity          CA      small SUV                    7
# 1603              Gasoline          CA   standard SUV                    5
# 1605              Gasoline          CA   standard SUV                    5
# 1607              Gasoline          CA   standard SUV                    5
# 1609  Gasoline/Electricity          CA   standard SUV                    7
#
#      city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score smartway
# 1          20      28      23                     5       No
# 3          19      27      22                     4       No
# 4          23      33      27                     6       No
# 6          20      32      24                     5       No
# 8          21      30      24                     5       No
# 10         20      29      23                     5       No
# 12         20      30      23                     5       No
# 14         24      34      28                     6       No
# 17         17      24      20                     4       No
# 22         24      31      27                     6       No
# 24         26      35      29                     6       No
# 26         22      30      25                     5       No
# 28         25      33      28                     6       No
# 30         24      34      27                     6       No
# 32         24      33      27                     6       No
# 34         27      37      31                     7      Yes
# 36         24      34      27                     6       No
# 38         24      33      27                     6       No
# 40         24      34      27                     6       No
# 42         24      34      27                     6       No
# 44         25      34      28                     6       No
# 46         22      31      26                     5       No
# 49         20      29      23                     5       No
# 51         20      29      23                     5       No
# 53         19      29      22                     4       No
# 55         20      28      23                     5       No
# 57         20      28      23                     5       No
# 58         23      27      25                     5       No
# 60         19      25      21                     4       No
# 63         19      25      21                     4       No
# ...       ...     ...     ...                   ...      ...
# 1551       17      23      19                     3       No
# 1553       25      36      29                     6       No
# 1555       22      32      26                     5       No
# 1556       22      33      26                     5       No
# 1559       22      30      25                     5       No
# 1561       25      36      29                     6       No
# 1563       22      33      26                     5       No
# 1565       20      27      22                     4       No
# 1567       24      34      27                     6       No
# 1569       22      31      25                     5       No
# 1570       23      32      26                     5       No
# 1573       23      32      26                     5       No
# 1575       22      31      25                     5       No
# 1577    26/70   33/72   29/71                    10    Elite
# 1579       25      36      29                     6       No
# 1581       22      32      26                     5       No
# 1582       22      33      26                     5       No
# 1585       22      30      25                     5       No
# 1587       20      27      22                     4       No
# 1589       24      34      27                     6       No
# 1591       22      31      25                     5       No
# 1593       23      31      26                     5       No
# 1595       22      29      25                     5       No
# 1597       22      28      24                     5       No
# 1599       21      27      23                     5       No
# 1601    26/60   28/58   26/59                    10    Elite
# 1603       22      29      25                     5       No
# 1605       22      28      24                     5       No
# 1607       20      27      23                     5       No
# 1609    26/63   30/61   27/62                    10    Elite
#
# [794 rows x 14 columns]

# %%
# print number of duplicates again to confirm dedupe - should both be 0

print(df_08.duplicated().sum())
df_18.duplicated().sum()
# Out:
# 23
# 3

# %%
# save progress for the next section
df_08.to_csv('data_08_v2.csv', index=False)
df_18.to_csv('data_18_v2.csv', index=False)
